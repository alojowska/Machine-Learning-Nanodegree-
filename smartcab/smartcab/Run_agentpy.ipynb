# %%
import pygame

# %run agent.py
# Out:
# /-------------------------
# | Training trial 1
# \-------------------------
#
# Environment.reset(): Trial set up with start = (4, 3), destination = (6, 5), deadline = 20
# Simulating trial. . .
# epsilon = 0.9000; alpha = 0.2500
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# Environment.step(): t = 0
# Environment.act() [POST]: location: (4, 3), heading: (1, 0), action: None, reward: -5.96115762417
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': 'right', 'left': None}, 'violation': 1, 'light': 'green', 'state': ('forward', 'green', None), 'deadline': 20, 't': 0, 'action': None, 'reward': -5.961157624170339, 'waypoint': 'forward'}
# Agent previous state: ('forward', 'green', None)
# Agent idled at a green light with no oncoming traffic. (rewarded -5.96)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# Environment.step(): t = 1
# ...

# %%
1/0.05
# Out:
# 20.0
