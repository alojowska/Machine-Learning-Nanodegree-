# %%
import pygame

# %run agent.py
# Out:
# /-------------------------
# | Training trial 1
# \-------------------------
#
# Environment.reset(): Trial set up with start = (5, 2), destination = (8, 4), deadline = 25
# Simulating trial. . .
# epsilon = 1.0000; alpha = 0.2500
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# Environment.step(): t = 0
# Environment.act() [POST]: location: (5, 2), heading: (1, 0), action: left, reward: -10.7582896399
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': None, 'left': None}, 'violation': 2, 'light': 'red', 'state': ('forward', 'red'), 'deadline': 25, 't': 0, 'action': 'left', 'reward': -10.758289639947913, 'waypoint': 'forward'}
# Agent previous state: ('forward', 'red')
# Agent attempted driving left through a red light. (rewarded -10.76)
# 96% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# Environment.step(): t = 1
# ...

# %%
1/0.05
# Out:
# 20.0
